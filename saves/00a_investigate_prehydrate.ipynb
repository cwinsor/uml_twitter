# %%
# Overview:
#
# Before rehydration there are two files:  .json and .json.csv
# This notebook investigates those.
#
# To do this:
# The files are resident on GPU host 12G disk.
# These get copied (just file explorer) to google drive folder
# "My Drive/colab_datasets" https://drive.google.com/drive/folders/1tDPMhQoyxrW01Evcrt3f6l_zDOWhGBa8?usp=share_link
#
# The script here opens that local .json files and investigates

# %%
# In summary - it gives just the basic (non-rehydrated info... tweet_id, user_id, created_at and somelocation info)

# %%
# !pip install ijson
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# python standard library imports
# from-imports follow regular imports
import re
import random
from math import sqrt
from collections import Counter
import datetime

# external libraries imports, grouped semantically
import torch
import numpy as np

import matplotlib.pyplot as plt
from tqdm.auto import tqdm
from IPython.display import clear_output, display

import ijson

# %%
# authenticate to google drive

# reference https://towardsdatascience.com/different-ways-to-connect-google-drive-to-a-google-colab-notebook-pt-1-de03433d2f7a
from pydrive.auth import GoogleAuth
from google.colab import drive
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
local_filename = "local_ids_en_geo_2020-02-01.json"
fid_rd = "1Kxa8i5dAv0GLZeGKluWCWlMKUfmay_1p"

# local_filename = "local_ids_en_geo_2020-02-01.json.csv"
# fid_rd = "1Ksxfx5mFWcYKLu4DbqwcbvcoPvnI189b" # ids_en_geo_2020-02-01.json.csv

drive_file = drive.CreateFile({'id': fid_rd})

# Download the file to a local disc
drive_file.GetContentFile(local_filename)
# df  = pd.read_csv("file.csv")
# df.head()

# %%
raw_list = []

with open(local_filename, "rb") as f:
    objects = ijson.items(f, "", multiple_values=True)
    obj_num = 0
    for object in objects:
        obj_num += 1
        print("------------------------------")
        print(object)
        for k, v in object.items():
            print(f"{k} {v}")

        if obj_num >= 2:
            assert False, "hold up"

        # if object["tweet_id"] == 1223491082425684000:
        #     print("found it")
        #     print("------------------------------")
        #     print(object)
        #     for k, v in object.items():
        #         print(f"{k} {v}")

        #     assert False, "hold up"
            
print("number of entries: ", len(raw_list))
# Out:
# ------------------------------
# {'tweet_id': '1223489703456006144', 'created_at': 'Sat Feb 01 06:14:11 +0000 2020', 'user_id': '30746211', 'geo_source': 'user_location', 'user_location': {'country_code': 'ca'}, 'geo': {}, 'place': {}, 'tweet_locations': [{'country_code': 'ua', 'state': 'Zhytomyr Oblast', 'county': 'Slovechne Amalgamated Territorial Community'}, {'country_code': 'es', 'state': 'Andalusia', 'county': 'Jaén', 'city': 'Jaén'}, {'country_code': 'cn', 'state': 'Hubei', 'county': "Jiang'an District", 'city': 'Wuhan'}, {'country_code': 'ca'}, {'country_code': 'us', 'state': 'Oklahoma', 'county': 'Texas'}, {'country_code': 'us', 'state': 'Maryland', 'county': "Queen Anne's County"}]}
# tweet_id 1223489703456006144
# created_at Sat Feb 01 06:14:11 +0000 2020
# user_id 30746211
# geo_source user_location
# user_location {'country_code': 'ca'}
# geo {}
# place {}
# ...
