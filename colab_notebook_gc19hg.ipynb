# %% [markdown]
# # **The GC19HG Project - Dataset Preprocessing**
# GC19HG (GeoCovid19 Heterogeneous Graph) is a social media research project that seeks to understand how the micro-level behaviors of millions of users combine to form macro-level topic trends. The work is based on the CrisisNLP GeoCov19 dataset - a set of tweets relating to Covid19 during the early months of 2020.
#
# The work is done by Chris Winsor as part of the Graph Data Analytics Research Group under professor Tingjian Ge at University of Massachusetts Lowell.
#
# Our approach uses a heterogeneous graph machine learning based on PyTorch Geometric (PyG) and self-supervised learning. The code here performs preprocessing of the raw data and preliminary attempts at modeling.

# %% [markdown]
# ## Installation

# %% [markdown]
# The cell below installs libraries and clones the repository which has the GC19HG preprocessing modules.
#
# The full code for GC19HG can be found on [Github](https://github.com/cwinsor/uml_twitter.git).

# %%
import os
import sys
print("version 3")
if 'google.colab' in sys.modules:
    print("host is colab")
    # %cd -q /content
    _ = !git clone https://github.com/cwinsor/uml_twitter.git
    # %cd -q uml_twitter/
    _ = !git pull
    # !pip install torch_geometric
    # !pip install sentence-transformers
    # !pip install ijson
else:
    print("host is traditional server")
# Out:
# version 3
# host is colab

# %% [markdown]
# ## Download some sample raw data (2 files)

# %%
import gdown
# !gdown '1cKrf5K1yDE4V8W1L5ISicMeNffdCZOIB'
# !gdown '1cCp4mXRvfhYVndJ9AO8RA2O-tYGBQaVU'
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1cKrf5K1yDE4V8W1L5ISicMeNffdCZOIB
# To: /content/uml_twitter/ids_geo_2020-02-01.jsonl
# 100% 1.25G/1.25G [00:08<00:00, 144MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1cCp4mXRvfhYVndJ9AO8RA2O-tYGBQaVU
# To: /content/uml_twitter/ids_geo_2020-02-02.jsonl
# 100% 2.84G/2.84G [00:30<00:00, 91.6MB/s]

# %% [markdown]
# ## Parse the raw data

# %%
# %run g40_preprocess.py --do_parse \
--parse_src_folder ./ \
--parse_dst_folder ./ \
--parse_file_list \
    ids_geo_2020-02-01.jsonl \
    ids_geo_2020-02-02.jsonl
# Out:
# INFO:root:args: Namespace(do_parse=True, parse_src_folder='./', parse_dst_folder='./', parse_file_list=['ids_geo_2020-02-01.jsonl', 'ids_geo_2020-02-02.jsonl'], perform_merge=False, merge_src_folder=None, merge_dst_folder=None, merge_file_list=None, do_filter=False, filter_src_folder=None, filter_dst_folder=None)
# INFO:root:start
# read raw files...
#  ids_geo_2020-02-01.jsonl
#  ids_geo_2020-02-02.jsonl
# write results...
# INFO:root:done
# done

# %%
  # %run g40_preprocess.py --do_filter \
  --filter_src_folder ./ \
  --filter_dst_folder ./
# Out:
# INFO:root:args: Namespace(do_parse=False, parse_src_folder=None, parse_dst_folder=None, parse_file_list=None, perform_merge=False, merge_src_folder=None, merge_dst_folder=None, merge_file_list=None, do_filter=True, filter_src_folder='./', filter_dst_folder='./')
# INFO:root:start
# after filtering:
# number of original tweets: 2314
# number of retweets: 14833
# number of edges: 14838
# INFO:root:done
# write results...
# done

# %%
# %run g41_train_test.py --src_folder ./
# Out:
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: bert-base-uncased
# create embeddings for original tweets using BERT-base-uncased
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name /root/.cache/torch/sentence_transformers/bert-base-uncased. Creating a new one with MEAN pooling.
# Some weights of the model checkpoint at /root/.cache/torch/sentence_transformers/bert-base-uncased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device: cpu
# sequence encoding using SentenceTransformer(
#   (0): Transformer({'max_seq_length': 512, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
# )
# Batches:   0%|          | 0/73 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /content/uml_twitter/g41_train_test.py in <module>
#     249 if __name__ == "__main__":
#     250     args = parser.parse_args()
# --> 251     main(args)
#
# /content/uml_twitter/g41_train_test.py in main(args)
#     157
#     158     print("create embeddings for original tweets using BERT-base-uncased")
# --> 159     original_tweet_x, original_tweet_mapping = load_nodes_from_file(
#     160         filename="originals_filtered.jsonl",
#     161         encoders={
#
# /content/uml_twitter/g41_train_test.py in load_nodes_from_file(filename, encoders, **kwargs)
#      53         for col, encoder in encoders.items():
#      54             column_of_data = [v[col] for _, v in the_data.items()]
# ---> 55             xs = encoder(column_of_data)
#      56             x = torch.cat((x, xs), dim=-1)
#      57
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# /content/uml_twitter/g41_train_test.py in __call__(self, sequence)
#      86     def __call__(self, sequence):
#      87         print(f"sequence encoding using {self.model}")
# ---> 88         x = self.model.encode(sequence, show_progress_bar=True,
#      89                               convert_to_tensor=True, device=self.device)
#      90         return x.cpu()
#
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/SentenceTransformer.py in encode(self, sentences, batch_size, show_progress_bar, output_value, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     163
#     164             with torch.no_grad():
# --> 165                 out_features = self.forward(features)
#     166
#     167                 if output_value == 'token_embeddings':
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     215     def forward(self, input):
#     216         for module in self:
# --> 217             input = module(input)
#     218         return input
#     219
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/models/Transformer.py in forward(self, features)
#      64             trans_features['token_type_ids'] = features['token_type_ids']
#      65
# ---> 66         output_states = self.auto_model(**trans_features, return_dict=False)
#      67         output_tokens = output_states[0]
#      68
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1018             past_key_values_length=past_key_values_length,
#    1019         )
# -> 1020         encoder_outputs = self.encoder(
#    1021             embedding_output,
#    1022             attention_mask=extended_attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     608                 )
#     609             else:
# --> 610                 layer_outputs = layer_module(
#     611                     hidden_states,
#     612                     attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     535             present_key_value = present_key_value + cross_attn_present_key_value
#     536
# --> 537         layer_output = apply_chunking_to_forward(
#     538             self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     539         )
#
# /usr/local/lib/python3.10/dist-packages/transformers/pytorch_utils.py in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     234         return torch.cat(output_chunks, dim=chunk_dim)
#     235
# --> 236     return forward_fn(*input_tensors)
#     237
#     238
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py in feed_forward_chunk(self, attention_output)
#     548     def feed_forward_chunk(self, attention_output):
#     549         intermediate_output = self.intermediate(attention_output)
# --> 550         layer_output = self.output(intermediate_output, attention_output)
#     551         return layer_output
#     552
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, input_tensor)
#     460
#     461     def forward(self, hidden_states: torch.Tensor, input_tensor: torch.Tensor) -> torch.Tensor:
# --> 462         hidden_states = self.dense(hidden_states)
#     463         hidden_states = self.dropout(hidden_states)
#     464         hidden_states = self.LayerNorm(hidden_states + input_tensor)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# KeyboardInterrupt:
